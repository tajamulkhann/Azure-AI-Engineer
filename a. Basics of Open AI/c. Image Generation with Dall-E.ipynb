# %% [markdown]
# ## Open AI

# %% [markdown]
# ### OpenAI API Call
#
# using OpenAi Model
#
# - GPT 4o
#
# `client.chat.completions.create(`
# `model="gpt-4o-mini",`
# `messages=[{"role":"user","content":"What is OpenAI`

# %%
import openai
from openai import OpenAI
import os
from dotenv import load_dotenv
load_dotenv()

# For Environments
os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY")

# Get API key
api_key = os.getenv("OPENAI_API_KEY")

# Initialize OpenAI client
client = OpenAI()

# Example chat completion
response = client.chat.completions.create(
    model="gpt-4o-mini",  # you can also use "gpt-4o", "gpt-4", etc.
    messages=[
        {"role": "user", "content": "Who is the Prime Minister of India?",
         "instructions": "Provide 1 line answer."}
    ]
)

print(response.choices[0].message.content)
# Out:
# As of my last training cut-off in October 2023, the Prime Minister of India is Narendra Modi. He has been in office since May 26, 2014. For the most current information, please verify with up-to-date sources.

# %% [markdown]
# ### Creating Embeddings
#
# Converting Text into Numerical Vectors using OpenAI's Embedding API.
#
# `client.embeddings.create(texts=["Hello world", "OpenAI"], engine="text-embedding-ada`

# %%
response = client.embeddings.create(input=["Hello world"], model="text-embedding-3-small")

print(response.data[0].embedding)
# Out:
# [-0.002078542485833168, -0.04908587411046028, 0.020946789532899857, 0.03135102614760399, -0.04530530795454979, -0.026402482762932777, -0.028999701142311096, 0.06030462309718132, -0.02571091614663601, -0.01482258178293705, 0.015444992110133171, -0.029983261600136757, -0.020393535494804382, -0.03334888815879822, 0.025833861902356148, 0.014207855798304081, -0.0700787678360939, 0.012432834133505821, 0.014791845344007015, 0.048839982599020004, 0.02073163539171219, -0.008890475146472454, -0.015114576555788517, -0.01661297120153904, 0.025926070287823677, -0.002902659587562084, -0.024327782914042473, 0.024281678721308708, 0.0017433245666325092, -0.055724915117025375, 0.02308296225965023, -0.045489728450775146, -0.008652268908917904, 0.0031619970686733723, 0.004583551082760096, 0.001794231589883566, 0.02669447846710682, 0.010158347897231579, -0.012056314386427402, -0.011472324840724468, -0.01491479016840458, -0.023129066452383995, 0.025357449427247047, 0.036822088062763214, -0.035500429570674896, 0.02126952074468136, -0.06307089328765869, 0.04038750007748604, 0.05354263633489609, 0.06153407692909241, -0.033656250685453415, -0.0066582513973116875, 0.02549576200544834, 0.10966712236404419, -0.004683443810790777, -0.03946541249752045, 0.007119296118617058, 0.05151404067873955, -0.026325643062591553, 0.027877826243638992, 0.030428938567638397, 0.020593322813510895, 0.01724306493997574, 0.012355993501842022, 0.0010844151256605983, 0.007092401850968599, -0.03706797957420349, 0.02352863922715187, -0.010665496811270714, 0.04084854573011398, -0.002132331021130085, 0.03136639669537544, -0.042723458260297775, -0.006758144591003656, -0.0472416952252388, -0.021807406097650528, -0.045674145221710205, 0.000996048329398036, 8.950746996561065e-05, -0.04745684936642647, -0.03294931724667549, 0.023421062156558037, -0.05286644026637077, -0.05621669441461563, -0.022560445591807365, 0.01804220862686634, -0.03590000048279762, 0.0011708609526976943, -0.006001262925565243, -0.019840283319354057, 0.011226434260606766, 0.0009922062745317817, -0.02010154165327549, 0.04512089118361473, 0.04137106239795685, 0.005490271840244532, -0.007296029478311539, 0.03915804997086525, 0.059720635414123535, -0.008675321005284786, 0.027908561751246452, -0.02403578720986843, 0.026264170184731483, -0.016028981655836105, 0.008867423050105572, 0.011725898832082748, -0.00017241144087165594, -0.04613519087433815, -0.025065453723073006, 0.004598919302225113, -0.11231044679880142, -0.015368150547146797, 0.013416395522654057, -0.03119734674692154, 0.00516754062846303, 0.03307225927710533, 0.08145119994878769, -0.05741541087627411, 0.017319906502962112, -0.06798870116472244, 0.020854581147432327, 0.0027163205668330193, -0.01771947741508484, -0.05855265632271767, -0.057937927544116974, -0.026341009885072708, -0.010511815547943115, 0.03749828785657883, -0.041647687554359436, 0.007199978921562433, 0.028999701142311096, 0.026771318167448044, 0.016397817060351372, -0.006566042546182871, -0.04711874946951866, 0.012717144563794136, -0.035654108971357346, -0.022852441295981407, -0.03442465886473656, 0.039772775024175644, 0.053757790476083755, -0.05102226138114929, 0.0027547411154955626, -0.04201652482151985, -0.0034386238548904657, -0.04201652482151985, -0.002111199777573347, 0.03301078826189041, -0.02317517250776291, 0.005620901007205248, 0.04386070370674133, 0.05858338996767998, -0.0580301396548748, 0.015275942161679268, 0.029399272054433823, -0.007226873189210892, 0.03534674644470215, -0.03503938391804695, -0.01109580509364605, 0.00738055445253849, 0.019871018826961517, 0.03190428018569946, -0.036576200276613235, -0.016151927411556244, -0.011426220647990704, 0.0034674389753490686, -0.0019296634709462523, 0.004141716752201319, -0.047733478248119354, 0.007107769604772329, 0.017289169132709503, 0.014154067263007164, -0.02305222675204277, -0.05621669441461563, -0.013554709032177925, 0.01499931514263153, 0.01747358776628971, -0.05243613198399544, -0.010680864565074444, -0.040664128959178925, 0.04155 ...

# %%
from openai import OpenAI
from dotenv import load_dotenv
import numpy as np
import os
load_dotenv('openai.env')


# Access the environment variables from the .env file
api_key = os.environ.get('OPENAI_API_KEY')
from openai import OpenAI
client = OpenAI()

def normalize_l2(x):
    x = np.array(x)
    if x.ndim == 1:
        norm = np.linalg.norm(x)
        if norm == 0:
            return x
        return x / norm
    else:
        norm = np.linalg.norm(x, 2, axis=1, keepdims=True)
        return np.where(norm == 0, x, x / norm)

response = client.embeddings.create(
    input="cat",
    model="text-embedding-3-small"
)

cut_dim = response.data[0].embedding[:7]
norm_dim = normalize_l2(cut_dim)
print(norm_dim)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[24], line 3
#       1 from openai import OpenAI
#       2 from dotenv import load_dotenv
# ----> 3 import numpy as np
#       4 import os
#       5 load_dotenv('openai.env')
#
# ModuleNotFoundError: No module named 'numpy'
